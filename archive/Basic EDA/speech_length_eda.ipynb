# %%
import pandas as pd

# %%
df = pd.read_csv('/home/raza/projects/Streaming-Pipeline-Parliamentary-Debates/data/preprocessed_england_speeches_sample_2015.csv')

# %%
# Distribution of chair column boolean?

print(df['chair'].value_counts(normalize=True))
# Out:
# chair
# False    1.0
# Name: proportion, dtype: float64

# %%
# Get a distribution graph and some statistics on the length of the speeches via the variable terms.

print(df['new_terms'].describe())
# Out:
# count    432716.000000
# mean        147.223572
# std         131.030337
# min           1.000000
# 25%          52.000000
# 50%          87.000000
# 75%         232.000000
# max         384.000000
# Name: new_terms, dtype: float64

# %%
# Granular Histogram of the terms column
# Some sort of distribution is visible, but it is hard to see the shape of the distribution.

df['new_terms'].hist(bins=1000)
# Out:
# <Axes: >

# %%
# What percentage of speeches are longer than 384 terms?

print((df['new_terms'] > 384).mean())
# Out:
# 0.0
